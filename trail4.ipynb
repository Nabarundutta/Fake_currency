# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
from einops import rearrange, repeat
from einops.layers.torch import Rearrange

# ✅ Device Setup
if torch.backends.mps.is_available():
    device = torch.device('mps')
    print('Using Apple MPS')
elif torch.cuda.is_available():
    device = torch.device('cuda')
    print('Using CUDA')
else:
    device = torch.device('cpu')
    print('Using CPU')

print(f'Device: {device}')
# Out:
# Using Apple MPS
# Device: mps

# %%
# Reuse the same HybridCNNViT class definition

class CNNFeatureExtractor(nn.Module):
    def __init__(self, in_channels=3, channels=[32, 64, 128]):
        super().__init__()
        layers = []
        prev_channels = in_channels
        for i, out_channels in enumerate(channels):
            layers.extend([
                nn.Conv2d(prev_channels, out_channels, kernel_size=3, 
                          stride=1 if i < len(channels)-1 else 2, padding=1),
                nn.BatchNorm2d(out_channels),
                nn.ReLU(inplace=True),
                nn.Dropout2d(p=0.1)
            ])
            if i < len(channels) - 1:
                layers.extend([
                    nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
                    nn.BatchNorm2d(out_channels),
                    nn.ReLU(inplace=True),
                    nn.MaxPool2d(2)
                ])
            prev_channels = out_channels
        self.cnn = nn.Sequential(*layers)

    def forward(self, x):
        return self.cnn(x)

class PatchEmbedding(nn.Module):
    def __init__(self, in_channels=128, embed_dim=256, patch_size=4):
        super().__init__()
        self.projection = nn.Sequential(
            nn.Conv2d(in_channels, embed_dim, kernel_size=patch_size, stride=patch_size),
            Rearrange('b e h w -> b (h w) e'),
        )

    def forward(self, x):
        return self.projection(x)

class DropPath(nn.Module):
    def __init__(self, drop_prob=0.0):
        super().__init__()
        self.drop_prob = drop_prob
    def forward(self, x):
        if self.drop_prob == 0. or not self.training:
            return x
        keep_prob = 1 - self.drop_prob
        shape = (x.shape[0],) + (1,) * (x.ndim - 1)
        random_tensor = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
        random_tensor.floor_()
        return x.div(keep_prob) * random_tensor

class MultiHeadAttention(nn.Module):
    def __init__(self, embed_dim, num_heads, dropout=0.1):
        super().__init__()
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.head_dim = embed_dim // num_heads
        self.qkv = nn.Linear(embed_dim, embed_dim * 3)
        self.attn_drop = nn.Dropout(dropout)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.proj_drop = nn.Dropout(dropout)

    def forward(self, x):
        B, N, C = x.shape
        qkv = self.qkv(x).reshape(B, N, 3, self.num_heads, self.head_dim).permute(2, 0, 3, 1, 4)
        q, k, v = qkv[0], qkv[1], qkv[2]
        attn = (q @ k.transpose(-2, -1)) * (self.head_dim ** -0.5)
        attn = F.softmax(attn, dim=-1)
        attn = self.attn_drop(attn)
        x = (attn @ v).transpose(1, 2).reshape(B, N, C)
        return self.proj_drop(self.proj(x))

class TransformerBlock(nn.Module):
    def __init__(self, embed_dim, num_heads, mlp_dim, dropout=0.1, drop_path=0.0):
        super().__init__()
        self.norm1 = nn.LayerNorm(embed_dim)
        self.attn = MultiHeadAttention(embed_dim, num_heads, dropout)
        self.norm2 = nn.LayerNorm(embed_dim)
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, mlp_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(mlp_dim, embed_dim),
            nn.Dropout(dropout)
        )
        self.drop_path = DropPath(drop_path) if drop_path > 0 else nn.Identity()

    def forward(self, x):
        x = x + self.drop_path(self.attn(self.norm1(x)))
        return x + self.drop_path(self.mlp(self.norm2(x)))

class HybridCNNViT(nn.Module):
    def __init__(self, img_size=32, patch_size=4, in_channels=3, num_classes=10,
                 cnn_channels=[32, 64, 128], embed_dim=256, num_heads=8,
                 num_layers=6, mlp_dim=512, dropout=0.1, drop_path_rate=0.1):
        super().__init__()
        self.cnn_features = CNNFeatureExtractor(in_channels, cnn_channels)
        self.patch_embed = PatchEmbedding(cnn_channels[-1], embed_dim, patch_size)
        num_patches = (img_size // (2 ** (len(cnn_channels) - 1)) // patch_size) ** 2
        self.pos_embedding = nn.Parameter(torch.randn(1, num_patches + 1, embed_dim))
        self.cls_token = nn.Parameter(torch.randn(1, 1, embed_dim))
        self.pos_drop = nn.Dropout(dropout)
        dpr = [x.item() for x in torch.linspace(0, drop_path_rate, num_layers)]
        self.transformer = nn.ModuleList([
            TransformerBlock(embed_dim, num_heads, mlp_dim, dropout, dpr[i])
            for i in range(num_layers)
        ])
        self.norm = nn.LayerNorm(embed_dim)
        self.head = nn.Sequential(nn.Dropout(dropout), nn.Linear(embed_dim, num_classes))

    def forward(self, x):
        x = self.cnn_features(x)
        x = self.patch_embed(x)
        B = x.shape[0]
        cls_tokens = repeat(self.cls_token, '1 1 d -> b 1 d', b=B)
        x = torch.cat([cls_tokens, x], dim=1)
        x = self.pos_drop(x + self.pos_embedding[:, :x.size(1)])
        for block in self.transformer:
            x = block(x)
        cls_token_final = self.norm(x)[:, 0]
        return self.head(cls_token_final)

# %%
# Load trained model
checkpoint = torch.load('best_hybrid_cnn_vit.pth', map_location=device)
model = HybridCNNViT(num_classes=10)
model.load_state_dict(checkpoint['model_state_dict'])
print(f"Loaded pretrained model with validation accuracy: {checkpoint['val_acc']:.2f}%")

# Freeze all layers
for param in model.parameters():
    param.requires_grad = False

# Replace classification head for binary classification
model.head = nn.Sequential(
    nn.Dropout(0.2),
    nn.Linear(256, 2)
)

model.to(device)
print("✅ Model modified for binary classification and frozen.")
# Out:
# Loaded pretrained model with validation accuracy: 86.84%
# ✅ Model modified for binary classification and frozen.

# %%
from torchvision import datasets
from torchvision import transforms
from torch.utils.data import DataLoader

# Define transforms (augmentations for training)
train_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2470, 0.2435, 0.2616])
])

val_transform = transforms.Compose([
    transforms.Resize((32, 32)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.4914, 0.4822, 0.4465],
                         std=[0.2470, 0.2435, 0.2616])
])

# Load your dataset from folders
train_dataset = datasets.ImageFolder(root='training', transform=train_transform)
val_dataset = datasets.ImageFolder(root='testing', transform=val_transform)

train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, num_workers=2)

print(f"Training samples: {len(train_dataset)}, Validation samples: {len(val_dataset)}")
print(f"Classes: {train_dataset.classes}")
# Out:
# Training samples: 2774, Validation samples: 594
# Classes: ['fake', 'real']

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.05)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6)

# %%
import torch
import torch.nn.functional as F
import torch.optim as optim
from tqdm import tqdm
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import CosineAnnealingLR

# -----------------------------------------------
# 🔧 Optimizer and Scheduler Setup
# -----------------------------------------------
optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=0.05)
scheduler = CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6)

# -----------------------------------------------
# 🧩 Training Loop with Gradual Unfreezing
# -----------------------------------------------
train_accs, val_accs = [], []

for epoch in range(100):
    print(f"\nEpoch {epoch+1}/100")
    print("-" * 60)
    model.train()
    
    running_corrects = 0
    total = 0
    running_loss = 0.0

    # -------------------- Training --------------------
    for images, labels in tqdm(train_loader, desc=f"Training Epoch {epoch+1}"):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()

        # Forward and backward in FP32 (safe for MPS)
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()

        # Gradient clipping
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        # Accuracy tracking
        _, preds = torch.max(outputs, 1)
        running_corrects += torch.sum(preds == labels)
        total += labels.size(0)
        running_loss += loss.item()
    
    train_acc = 100 * running_corrects / total
    train_accs.append(train_acc.item())
    avg_train_loss = running_loss / len(train_loader)

    # -------------------- Validation --------------------
    model.eval()
    val_corrects = 0
    val_total = 0
    val_loss = 0.0

    with torch.no_grad():
        for images, labels in tqdm(val_loader, desc="Validating"):
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            _, preds = torch.max(outputs, 1)
            val_corrects += torch.sum(preds == labels)
            val_total += labels.size(0)
            val_loss += loss.item()

    val_acc = 100 * val_corrects / val_total
    val_accs.append(val_acc.item())

    # Step the LR scheduler
    scheduler.step()

    # -------------------- Fine-tuning Trigger --------------------
    if epoch == 5:
        print("\n🔓 Unfreezing Transformer + CNN top layers for fine-tuning...")
        for name, param in model.named_parameters():
            if any(key in name for key in ["transformer", "cnn_features"]):
                param.requires_grad = True
        # Reduce learning rate to avoid catastrophic forgetting
        for g in optimizer.param_groups:
            g['lr'] = 1e-4
        print("✓ Transformer and CNN layers unfrozen. Fine-tuning at LR = 1e-4")

    # -------------------- Epoch Summary --------------------
    print(f"Train Loss: {avg_train_loss:.4f} | Train Accuracy: {train_acc:.2f}%")
    print(f"Val Loss: {val_loss/len(val_loader):.4f} | Val Accuracy: {val_acc:.2f}%")
    print(f"Current LR: {optimizer.param_groups[0]['lr']:.6f}")

# -----------------------------------------------
# 📈 Plot Accuracy Curves
# -----------------------------------------------
plt.figure(figsize=(8, 5))
plt.plot(train_accs, label='Train Accuracy', marker='o')
plt.plot(val_accs, label='Validation Accuracy', marker='s')
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy (%)', fontsize=12)
plt.title('Fine-Tuning Accuracy Curve', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Epoch 1/100
# ------------------------------------------------------------
# Training Epoch 1: 100%|██████████| 44/44 [00:22<00:00,  1.97it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.37s/it]
# Train Loss: 0.6565 | Train Accuracy: 61.82%
# Val Loss: 0.6077 | Val Accuracy: 67.68%
# Current LR: 0.000976
#
# Epoch 2/100
# ------------------------------------------------------------
# Training Epoch 2: 100%|██████████| 44/44 [00:16<00:00,  2.66it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.38s/it]
# Train Loss: 0.6309 | Train Accuracy: 65.36%
# Val Loss: 0.5859 | Val Accuracy: 69.19%
# Current LR: 0.000905
#
# Epoch 3/100
# ------------------------------------------------------------
# Training Epoch 3: 100%|██████████| 44/44 [00:17<00:00,  2.53it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.6337 | Train Accuracy: 65.93%
# Val Loss: 0.5818 | Val Accuracy: 70.37%
# Current LR: 0.000794
#
# Epoch 4/100
# ------------------------------------------------------------
# Training Epoch 4: 100%|██████████| 44/44 [00:16<00:00,  2.70it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Train Loss: 0.6196 | Train Accuracy: 65.18%
# Val Loss: 0.5770 | Val Accuracy: 70.20%
# Current LR: 0.000655
#
# Epoch 5/100
# ------------------------------------------------------------
# Training Epoch 5: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.6281 | Train Accuracy: 64.38%
# Val Loss: 0.5723 | Val Accuracy: 70.37%
# Current LR: 0.000501
#
# Epoch 6/100
# ------------------------------------------------------------
# Training Epoch 6: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# 🔓 Unfreezing Transformer + CNN top layers for fine-tuning...
# ✓ Transformer and CNN layers unfrozen. Fine-tuning at LR = 1e-4
# Train Loss: 0.6193 | Train Accuracy: 66.51%
# Val Loss: 0.5693 | Val Accuracy: 71.21%
# Current LR: 0.000100
#
# Epoch 7/100
# ------------------------------------------------------------
# Training Epoch 7: 100%|██████████| 44/44 [00:19<00:00,  2.20it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Train Loss: 0.5367 | Train Accuracy: 74.22%
# Val Loss: 0.3457 | Val Accuracy: 89.06%
# Current LR: 0.000060
#
# Epoch 8/100
# ------------------------------------------------------------
# Training Epoch 8: 100%|██████████| 44/44 [00:16<00:00,  2.59it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.38s/it]
# Train Loss: 0.4080 | Train Accuracy: 81.94%
# Val Loss: 0.2665 | Val Accuracy: 91.92%
# Current LR: 0.000028
#
# Epoch 9/100
# ------------------------------------------------------------
# Training Epoch 9: 100%|██████████| 44/44 [00:17<00:00,  2.53it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.3695 | Train Accuracy: 83.78%
# Val Loss: 0.2416 | Val Accuracy: 92.42%
# Current LR: 0.000008
#
# Epoch 10/100
# ------------------------------------------------------------
# Training Epoch 10: 100%|██████████| 44/44 [00:16<00:00,  2.63it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.3554 | Train Accuracy: 84.79%
# Val Loss: 0.2376 | Val Accuracy: 92.26%
# Current LR: 0.000001
#
# Epoch 11/100
# ------------------------------------------------------------
# Training Epoch 11: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.3529 | Train Accuracy: 85.69%
# Val Loss: 0.2377 | Val Accuracy: 92.26%
# Current LR: 0.000025
#
# Epoch 12/100
# ------------------------------------------------------------
# Training Epoch 12: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.3397 | Train Accuracy: 86.66%
# Val Loss: 0.2218 | Val Accuracy: 92.42%
# Current LR: 0.000096
#
# Epoch 13/100
# ------------------------------------------------------------
# Training Epoch 13: 100%|██████████| 44/44 [00:16<00:00,  2.66it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.3197 | Train Accuracy: 86.05%
# Val Loss: 0.1908 | Val Accuracy: 92.93%
# Current LR: 0.000207
#
# Epoch 14/100
# ------------------------------------------------------------
# Training Epoch 14: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.2753 | Train Accuracy: 88.21%
# Val Loss: 0.1680 | Val Accuracy: 93.27%
# Current LR: 0.000346
#
# Epoch 15/100
# ------------------------------------------------------------
# Training Epoch 15: 100%|██████████| 44/44 [00:18<00:00,  2.39it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.37s/it]
# Train Loss: 0.2305 | Train Accuracy: 90.45%
# Val Loss: 0.1396 | Val Accuracy: 94.44%
# Current LR: 0.000501
#
# Epoch 16/100
# ------------------------------------------------------------
# Training Epoch 16: 100%|██████████| 44/44 [14:37<00:00, 19.94s/it]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.1873 | Train Accuracy: 92.57%
# Val Loss: 0.1848 | Val Accuracy: 92.42%
# Current LR: 0.000655
#
# Epoch 17/100
# ------------------------------------------------------------
# Training Epoch 17: 100%|██████████| 44/44 [00:17<00:00,  2.55it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.1992 | Train Accuracy: 92.03%
# Val Loss: 0.1379 | Val Accuracy: 93.60%
# Current LR: 0.000794
#
# Epoch 18/100
# ------------------------------------------------------------
# Training Epoch 18: 100%|██████████| 44/44 [00:17<00:00,  2.47it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.39s/it]
# Train Loss: 0.1471 | Train Accuracy: 94.30%
# Val Loss: 0.1459 | Val Accuracy: 93.10%
# Current LR: 0.000905
#
# Epoch 19/100
# ------------------------------------------------------------
# Training Epoch 19: 100%|██████████| 44/44 [00:16<00:00,  2.62it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Train Loss: 0.1499 | Train Accuracy: 94.16%
# Val Loss: 0.1656 | Val Accuracy: 91.58%
# Current LR: 0.000976
#
# Epoch 20/100
# ------------------------------------------------------------
# Training Epoch 20: 100%|██████████| 44/44 [00:16<00:00,  2.61it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.1318 | Train Accuracy: 95.17%
# Val Loss: 0.1061 | Val Accuracy: 96.30%
# Current LR: 0.001000
#
# Epoch 21/100
# ------------------------------------------------------------
# Training Epoch 21: 100%|██████████| 44/44 [00:16<00:00,  2.66it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.1230 | Train Accuracy: 95.42%
# Val Loss: 0.1220 | Val Accuracy: 96.13%
# Current LR: 0.000976
#
# Epoch 22/100
# ------------------------------------------------------------
# Training Epoch 22: 100%|██████████| 44/44 [00:17<00:00,  2.56it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.1145 | Train Accuracy: 95.57%
# Val Loss: 0.1059 | Val Accuracy: 96.80%
# Current LR: 0.000905
#
# Epoch 23/100
# ------------------------------------------------------------
# Training Epoch 23: 100%|██████████| 44/44 [00:17<00:00,  2.57it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0968 | Train Accuracy: 96.32%
# Val Loss: 0.1254 | Val Accuracy: 93.94%
# Current LR: 0.000794
#
# Epoch 24/100
# ------------------------------------------------------------
# Training Epoch 24: 100%|██████████| 44/44 [00:16<00:00,  2.59it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.0908 | Train Accuracy: 96.58%
# Val Loss: 0.0987 | Val Accuracy: 96.80%
# Current LR: 0.000655
#
# Epoch 25/100
# ------------------------------------------------------------
# Training Epoch 25: 100%|██████████| 44/44 [00:17<00:00,  2.53it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.39s/it]
# Train Loss: 0.0900 | Train Accuracy: 97.01%
# Val Loss: 0.1132 | Val Accuracy: 95.96%
# Current LR: 0.000501
#
# Epoch 26/100
# ------------------------------------------------------------
# Training Epoch 26: 100%|██████████| 44/44 [00:16<00:00,  2.59it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.37s/it]
# Train Loss: 0.0826 | Train Accuracy: 97.08%
# Val Loss: 0.0987 | Val Accuracy: 95.96%
# Current LR: 0.000346
#
# Epoch 27/100
# ------------------------------------------------------------
# Training Epoch 27: 100%|██████████| 44/44 [00:16<00:00,  2.62it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.0603 | Train Accuracy: 97.76%
# Val Loss: 0.1438 | Val Accuracy: 95.12%
# Current LR: 0.000207
#
# Epoch 28/100
# ------------------------------------------------------------
# Training Epoch 28: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.37s/it]
# Train Loss: 0.0542 | Train Accuracy: 98.13%
# Val Loss: 0.0985 | Val Accuracy: 96.46%
# Current LR: 0.000096
#
# Epoch 29/100
# ------------------------------------------------------------
# Training Epoch 29: 100%|██████████| 44/44 [00:16<00:00,  2.63it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.0424 | Train Accuracy: 98.63%
# Val Loss: 0.0928 | Val Accuracy: 96.46%
# Current LR: 0.000025
#
# Epoch 30/100
# ------------------------------------------------------------
# Training Epoch 30: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0485 | Train Accuracy: 98.38%
# Val Loss: 0.1040 | Val Accuracy: 96.46%
# Current LR: 0.000001
#
# Epoch 31/100
# ------------------------------------------------------------
# Training Epoch 31: 100%|██████████| 44/44 [00:17<00:00,  2.54it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.0445 | Train Accuracy: 98.56%
# Val Loss: 0.0958 | Val Accuracy: 96.63%
# Current LR: 0.000025
#
# Epoch 32/100
# ------------------------------------------------------------
# Training Epoch 32: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0579 | Train Accuracy: 98.16%
# Val Loss: 0.0979 | Val Accuracy: 96.30%
# Current LR: 0.000096
#
# Epoch 33/100
# ------------------------------------------------------------
# Training Epoch 33: 100%|██████████| 44/44 [00:16<00:00,  2.60it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.37s/it]
# Train Loss: 0.0510 | Train Accuracy: 98.20%
# Val Loss: 0.0981 | Val Accuracy: 96.80%
# Current LR: 0.000207
#
# Epoch 34/100
# ------------------------------------------------------------
# Training Epoch 34: 100%|██████████| 44/44 [00:16<00:00,  2.66it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0389 | Train Accuracy: 98.67%
# Val Loss: 0.0883 | Val Accuracy: 96.80%
# Current LR: 0.000346
#
# Epoch 35/100
# ------------------------------------------------------------
# Training Epoch 35: 100%|██████████| 44/44 [00:17<00:00,  2.48it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.0545 | Train Accuracy: 98.09%
# Val Loss: 0.1005 | Val Accuracy: 96.46%
# Current LR: 0.000501
#
# Epoch 36/100
# ------------------------------------------------------------
# Training Epoch 36: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0478 | Train Accuracy: 98.41%
# Val Loss: 0.1354 | Val Accuracy: 96.13%
# Current LR: 0.000655
#
# Epoch 37/100
# ------------------------------------------------------------
# Training Epoch 37: 100%|██████████| 44/44 [00:16<00:00,  2.61it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.0569 | Train Accuracy: 98.16%
# Val Loss: 0.1683 | Val Accuracy: 94.95%
# Current LR: 0.000794
#
# Epoch 38/100
# ------------------------------------------------------------
# Training Epoch 38: 100%|██████████| 44/44 [00:16<00:00,  2.64it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.37s/it]
# Train Loss: 0.0733 | Train Accuracy: 97.40%
# Val Loss: 0.1585 | Val Accuracy: 94.95%
# Current LR: 0.000905
#
# Epoch 39/100
# ------------------------------------------------------------
# Training Epoch 39: 100%|██████████| 44/44 [00:17<00:00,  2.58it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0692 | Train Accuracy: 97.37%
# Val Loss: 0.1214 | Val Accuracy: 95.45%
# Current LR: 0.000976
#
# Epoch 40/100
# ------------------------------------------------------------
# Training Epoch 40: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.37s/it]
# Train Loss: 0.0614 | Train Accuracy: 98.05%
# Val Loss: 0.1741 | Val Accuracy: 95.12%
# Current LR: 0.001000
#
# Epoch 41/100
# ------------------------------------------------------------
# Training Epoch 41: 100%|██████████| 44/44 [00:17<00:00,  2.53it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0760 | Train Accuracy: 97.73%
# Val Loss: 0.1085 | Val Accuracy: 96.46%
# Current LR: 0.000976
#
# Epoch 42/100
# ------------------------------------------------------------
# Training Epoch 42: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0733 | Train Accuracy: 97.66%
# Val Loss: 0.1267 | Val Accuracy: 95.45%
# Current LR: 0.000905
#
# Epoch 43/100
# ------------------------------------------------------------
# Training Epoch 43: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0684 | Train Accuracy: 97.69%
# Val Loss: 0.1495 | Val Accuracy: 96.46%
# Current LR: 0.000794
#
# Epoch 44/100
# ------------------------------------------------------------
# Training Epoch 44: 100%|██████████| 44/44 [00:16<00:00,  2.63it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0540 | Train Accuracy: 98.13%
# Val Loss: 0.1442 | Val Accuracy: 95.45%
# Current LR: 0.000655
#
# Epoch 45/100
# ------------------------------------------------------------
# Training Epoch 45: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0429 | Train Accuracy: 98.52%
# Val Loss: 0.1400 | Val Accuracy: 95.96%
# Current LR: 0.000501
#
# Epoch 46/100
# ------------------------------------------------------------
# Training Epoch 46: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0390 | Train Accuracy: 98.67%
# Val Loss: 0.1272 | Val Accuracy: 96.80%
# Current LR: 0.000346
#
# Epoch 47/100
# ------------------------------------------------------------
# Training Epoch 47: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Train Loss: 0.0479 | Train Accuracy: 98.49%
# Val Loss: 0.1497 | Val Accuracy: 95.79%
# Current LR: 0.000207
#
# Epoch 48/100
# ------------------------------------------------------------
# Training Epoch 48: 100%|██████████| 44/44 [00:16<00:00,  2.62it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.0319 | Train Accuracy: 98.95%
# Val Loss: 0.1303 | Val Accuracy: 95.96%
# Current LR: 0.000096
#
# Epoch 49/100
# ------------------------------------------------------------
# Training Epoch 49: 100%|██████████| 44/44 [00:16<00:00,  2.64it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0308 | Train Accuracy: 99.10%
# Val Loss: 0.1415 | Val Accuracy: 96.30%
# Current LR: 0.000025
#
# Epoch 50/100
# ------------------------------------------------------------
# Training Epoch 50: 100%|██████████| 44/44 [00:16<00:00,  2.61it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.0279 | Train Accuracy: 99.03%
# Val Loss: 0.1391 | Val Accuracy: 95.96%
# Current LR: 0.000001
#
# Epoch 51/100
# ------------------------------------------------------------
# Training Epoch 51: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0269 | Train Accuracy: 99.24%
# Val Loss: 0.1343 | Val Accuracy: 96.46%
# Current LR: 0.000025
#
# Epoch 52/100
# ------------------------------------------------------------
# Training Epoch 52: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0176 | Train Accuracy: 99.53%
# Val Loss: 0.1426 | Val Accuracy: 95.96%
# Current LR: 0.000096
#
# Epoch 53/100
# ------------------------------------------------------------
# Training Epoch 53: 100%|██████████| 44/44 [00:16<00:00,  2.62it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Train Loss: 0.0234 | Train Accuracy: 99.06%
# Val Loss: 0.1493 | Val Accuracy: 95.96%
# Current LR: 0.000207
#
# Epoch 54/100
# ------------------------------------------------------------
# Training Epoch 54: 100%|██████████| 44/44 [00:16<00:00,  2.62it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.0243 | Train Accuracy: 99.28%
# Val Loss: 0.1273 | Val Accuracy: 96.80%
# Current LR: 0.000346
#
# Epoch 55/100
# ------------------------------------------------------------
# Training Epoch 55: 100%|██████████| 44/44 [00:17<00:00,  2.59it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.0326 | Train Accuracy: 99.03%
# Val Loss: 0.1480 | Val Accuracy: 96.46%
# Current LR: 0.000501
#
# Epoch 56/100
# ------------------------------------------------------------
# Training Epoch 56: 100%|██████████| 44/44 [00:17<00:00,  2.55it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# Train Loss: 0.0312 | Train Accuracy: 98.99%
# Val Loss: 0.1930 | Val Accuracy: 94.78%
# Current LR: 0.000655
#
# Epoch 57/100
# ------------------------------------------------------------
# Training Epoch 57: 100%|██████████| 44/44 [00:16<00:00,  2.63it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Train Loss: 0.0427 | Train Accuracy: 98.59%
# Val Loss: 0.1704 | Val Accuracy: 95.96%
# Current LR: 0.000794
#
# Epoch 58/100
# ------------------------------------------------------------
# Training Epoch 58: 100%|██████████| 44/44 [00:17<00:00,  2.54it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Train Loss: 0.0421 | Train Accuracy: 98.70%
# Val Loss: 0.2517 | Val Accuracy: 93.94%
# Current LR: 0.000905
#
# Epoch 59/100
# ------------------------------------------------------------
# Training Epoch 59: 100%|██████████| 44/44 [00:17<00:00,  2.51it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0448 | Train Accuracy: 98.41%
# Val Loss: 0.1520 | Val Accuracy: 95.12%
# Current LR: 0.000976
#
# Epoch 60/100
# ------------------------------------------------------------
# Training Epoch 60: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0473 | Train Accuracy: 98.41%
# Val Loss: 0.1810 | Val Accuracy: 95.96%
# Current LR: 0.001000
#
# Epoch 61/100
# ------------------------------------------------------------
# Training Epoch 61: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Train Loss: 0.0613 | Train Accuracy: 97.73%
# Val Loss: 0.2010 | Val Accuracy: 94.78%
# Current LR: 0.000976
#
# Epoch 62/100
# ------------------------------------------------------------
# Training Epoch 62: 100%|██████████| 44/44 [00:16<00:00,  2.63it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0493 | Train Accuracy: 97.98%
# Val Loss: 0.1715 | Val Accuracy: 94.61%
# Current LR: 0.000905
#
# Epoch 63/100
# ------------------------------------------------------------
# Training Epoch 63: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0364 | Train Accuracy: 98.59%
# Val Loss: 0.1936 | Val Accuracy: 95.62%
# Current LR: 0.000794
#
# Epoch 64/100
# ------------------------------------------------------------
# Training Epoch 64: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0518 | Train Accuracy: 98.27%
# Val Loss: 0.1592 | Val Accuracy: 95.62%
# Current LR: 0.000655
#
# Epoch 65/100
# ------------------------------------------------------------
# Training Epoch 65: 100%|██████████| 44/44 [00:16<00:00,  2.61it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0411 | Train Accuracy: 98.85%
# Val Loss: 0.1857 | Val Accuracy: 96.13%
# Current LR: 0.000501
#
# Epoch 66/100
# ------------------------------------------------------------
# Training Epoch 66: 100%|██████████| 44/44 [00:16<00:00,  2.65it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0362 | Train Accuracy: 98.92%
# Val Loss: 0.1584 | Val Accuracy: 96.13%
# Current LR: 0.000346
#
# Epoch 67/100
# ------------------------------------------------------------
# Training Epoch 67: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0226 | Train Accuracy: 99.06%
# Val Loss: 0.1686 | Val Accuracy: 96.13%
# Current LR: 0.000207
#
# Epoch 68/100
# ------------------------------------------------------------
# Training Epoch 68: 100%|██████████| 44/44 [00:16<00:00,  2.70it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0153 | Train Accuracy: 99.32%
# Val Loss: 0.1729 | Val Accuracy: 95.96%
# Current LR: 0.000096
#
# Epoch 69/100
# ------------------------------------------------------------
# Training Epoch 69: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0172 | Train Accuracy: 99.50%
# Val Loss: 0.1780 | Val Accuracy: 95.96%
# Current LR: 0.000025
#
# Epoch 70/100
# ------------------------------------------------------------
# Training Epoch 70: 100%|██████████| 44/44 [00:16<00:00,  2.64it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0062 | Train Accuracy: 99.89%
# Val Loss: 0.1829 | Val Accuracy: 95.96%
# Current LR: 0.000001
#
# Epoch 71/100
# ------------------------------------------------------------
# Training Epoch 71: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0182 | Train Accuracy: 99.46%
# Val Loss: 0.1827 | Val Accuracy: 95.96%
# Current LR: 0.000025
#
# Epoch 72/100
# ------------------------------------------------------------
# Training Epoch 72: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0170 | Train Accuracy: 99.39%
# Val Loss: 0.1840 | Val Accuracy: 95.96%
# Current LR: 0.000096
#
# Epoch 73/100
# ------------------------------------------------------------
# Training Epoch 73: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0160 | Train Accuracy: 99.46%
# Val Loss: 0.1915 | Val Accuracy: 95.96%
# Current LR: 0.000207
#
# Epoch 74/100
# ------------------------------------------------------------
# Training Epoch 74: 100%|██████████| 44/44 [00:16<00:00,  2.66it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0136 | Train Accuracy: 99.42%
# Val Loss: 0.2041 | Val Accuracy: 95.96%
# Current LR: 0.000346
#
# Epoch 75/100
# ------------------------------------------------------------
# Training Epoch 75: 100%|██████████| 44/44 [00:16<00:00,  2.70it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0217 | Train Accuracy: 99.39%
# Val Loss: 0.2029 | Val Accuracy: 96.13%
# Current LR: 0.000500
#
# Epoch 76/100
# ------------------------------------------------------------
# Training Epoch 76: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0267 | Train Accuracy: 99.17%
# Val Loss: 0.2190 | Val Accuracy: 95.29%
# Current LR: 0.000655
#
# Epoch 77/100
# ------------------------------------------------------------
# Training Epoch 77: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0249 | Train Accuracy: 99.35%
# Val Loss: 0.1880 | Val Accuracy: 95.62%
# Current LR: 0.000794
#
# Epoch 78/100
# ------------------------------------------------------------
# Training Epoch 78: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0303 | Train Accuracy: 99.03%
# Val Loss: 0.2530 | Val Accuracy: 94.61%
# Current LR: 0.000905
#
# Epoch 79/100
# ------------------------------------------------------------
# Training Epoch 79: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0376 | Train Accuracy: 98.85%
# Val Loss: 0.2354 | Val Accuracy: 94.78%
# Current LR: 0.000976
#
# Epoch 80/100
# ------------------------------------------------------------
# Training Epoch 80: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0487 | Train Accuracy: 98.23%
# Val Loss: 0.1644 | Val Accuracy: 96.46%
# Current LR: 0.001000
#
# Epoch 81/100
# ------------------------------------------------------------
# Training Epoch 81: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0548 | Train Accuracy: 98.20%
# Val Loss: 0.1687 | Val Accuracy: 94.95%
# Current LR: 0.000976
#
# Epoch 82/100
# ------------------------------------------------------------
# Training Epoch 82: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0465 | Train Accuracy: 98.27%
# Val Loss: 0.1920 | Val Accuracy: 94.28%
# Current LR: 0.000905
#
# Epoch 83/100
# ------------------------------------------------------------
# Training Epoch 83: 100%|██████████| 44/44 [00:16<00:00,  2.70it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0345 | Train Accuracy: 98.92%
# Val Loss: 0.1740 | Val Accuracy: 96.13%
# Current LR: 0.000794
#
# Epoch 84/100
# ------------------------------------------------------------
# Training Epoch 84: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0332 | Train Accuracy: 98.81%
# Val Loss: 0.2182 | Val Accuracy: 94.95%
# Current LR: 0.000655
#
# Epoch 85/100
# ------------------------------------------------------------
# Training Epoch 85: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0275 | Train Accuracy: 98.95%
# Val Loss: 0.1822 | Val Accuracy: 95.96%
# Current LR: 0.000500
#
# Epoch 86/100
# ------------------------------------------------------------
# Training Epoch 86: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0189 | Train Accuracy: 99.42%
# Val Loss: 0.1917 | Val Accuracy: 96.13%
# Current LR: 0.000346
#
# Epoch 87/100
# ------------------------------------------------------------
# Training Epoch 87: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0239 | Train Accuracy: 99.24%
# Val Loss: 0.1523 | Val Accuracy: 96.63%
# Current LR: 0.000207
#
# Epoch 88/100
# ------------------------------------------------------------
# Training Epoch 88: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0164 | Train Accuracy: 99.50%
# Val Loss: 0.1791 | Val Accuracy: 95.96%
# Current LR: 0.000096
#
# Epoch 89/100
# ------------------------------------------------------------
# Training Epoch 89: 100%|██████████| 44/44 [00:16<00:00,  2.71it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0108 | Train Accuracy: 99.57%
# Val Loss: 0.1719 | Val Accuracy: 96.30%
# Current LR: 0.000025
#
# Epoch 90/100
# ------------------------------------------------------------
# Training Epoch 90: 100%|██████████| 44/44 [00:16<00:00,  2.66it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0131 | Train Accuracy: 99.64%
# Val Loss: 0.1773 | Val Accuracy: 96.30%
# Current LR: 0.000001
#
# Epoch 91/100
# ------------------------------------------------------------
# Training Epoch 91: 100%|██████████| 44/44 [00:16<00:00,  2.68it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0127 | Train Accuracy: 99.50%
# Val Loss: 0.1791 | Val Accuracy: 96.30%
# Current LR: 0.000025
#
# Epoch 92/100
# ------------------------------------------------------------
# Training Epoch 92: 100%|██████████| 44/44 [00:16<00:00,  2.69it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0094 | Train Accuracy: 99.71%
# Val Loss: 0.1763 | Val Accuracy: 96.13%
# Current LR: 0.000096
#
# Epoch 93/100
# ------------------------------------------------------------
# Training Epoch 93: 100%|██████████| 44/44 [00:16<00:00,  2.71it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0128 | Train Accuracy: 99.68%
# Val Loss: 0.1842 | Val Accuracy: 96.13%
# Current LR: 0.000207
#
# Epoch 94/100
# ------------------------------------------------------------
# Training Epoch 94: 100%|██████████| 44/44 [00:16<00:00,  2.70it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0190 | Train Accuracy: 99.32%
# Val Loss: 0.1817 | Val Accuracy: 95.29%
# Current LR: 0.000346
#
# Epoch 95/100
# ------------------------------------------------------------
# Training Epoch 95: 100%|██████████| 44/44 [00:16<00:00,  2.70it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0110 | Train Accuracy: 99.71%
# Val Loss: 0.2058 | Val Accuracy: 96.30%
# Current LR: 0.000501
#
# Epoch 96/100
# ------------------------------------------------------------
# Training Epoch 96: 100%|██████████| 44/44 [00:16<00:00,  2.66it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.31s/it]
# Train Loss: 0.0198 | Train Accuracy: 99.46%
# Val Loss: 0.2532 | Val Accuracy: 94.28%
# Current LR: 0.000655
#
# Epoch 97/100
# ------------------------------------------------------------
# Training Epoch 97: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.38s/it]
# Train Loss: 0.0243 | Train Accuracy: 99.21%
# Val Loss: 0.2305 | Val Accuracy: 94.11%
# Current LR: 0.000794
#
# Epoch 98/100
# ------------------------------------------------------------
# Training Epoch 98: 100%|██████████| 44/44 [00:16<00:00,  2.66it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]
# Train Loss: 0.0242 | Train Accuracy: 99.24%
# Val Loss: 0.1458 | Val Accuracy: 96.46%
# Current LR: 0.000905
#
# Epoch 99/100
# ------------------------------------------------------------
# Training Epoch 99: 100%|██████████| 44/44 [00:16<00:00,  2.67it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.34s/it]
# Train Loss: 0.0260 | Train Accuracy: 99.13%
# Val Loss: 0.2205 | Val Accuracy: 94.78%
# Current LR: 0.000976
#
# Epoch 100/100
# ------------------------------------------------------------
# Training Epoch 100: 100%|██████████| 44/44 [00:16<00:00,  2.64it/s]
# Validating: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# Train Loss: 0.0414 | Train Accuracy: 98.31%
# Val Loss: 0.1682 | Val Accuracy: 95.45%
# Current LR: 0.001000

# %%
model.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for images, labels in val_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        y_true.extend(labels.cpu().numpy())
        y_pred.extend(preds.cpu().numpy())

cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='coolwarm', xticklabels=['fake', 'real'], yticklabels=['fake', 'real'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix - Binary Classification')
plt.show()

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=['fake', 'real']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         fake       0.95      0.96      0.95       297
#         real       0.96      0.95      0.95       297
#
#     accuracy                           0.95       594
#    macro avg       0.95      0.95      0.95       594
# weighted avg       0.95      0.95      0.95       594

# %%
plt.figure(figsize=(8,5))
plt.plot(train_accs, label='Train Accuracy', marker='o')
plt.plot(val_accs, label='Validation Accuracy', marker='s')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy Curve per Epoch')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
print("\nTRANSFER LEARNING SUMMARY")
print("="*50)
print("✓ Base Model: Hybrid CNN-ViT (pretrained on CIFAR-10)")
print("✓ Task: Binary Classification (Cats vs Dogs)")
print("✓ Feature Extractor: Frozen CNN + ViT layers")
print("✓ Trainable Head: Single linear layer (256 → 2)")
print("✓ Optimizer: AdamW (LR=1e-3)")
print("✓ Metrics: Accuracy, Confusion Matrix, Classification Report")
print("✓ Hardware: MPS / CUDA supported")
print("="*50)
# Out:
# TRANSFER LEARNING SUMMARY
# ==================================================
# ✓ Base Model: Hybrid CNN-ViT (pretrained on CIFAR-10)
# ✓ Task: Binary Classification (Cats vs Dogs)
# ✓ Feature Extractor: Frozen CNN + ViT layers
# ✓ Trainable Head: Single linear layer (256 → 2)
# ✓ Optimizer: AdamW (LR=1e-3)
# ✓ Metrics: Accuracy, Confusion Matrix, Classification Report
# ✓ Hardware: MPS / CUDA supported
# ==================================================
